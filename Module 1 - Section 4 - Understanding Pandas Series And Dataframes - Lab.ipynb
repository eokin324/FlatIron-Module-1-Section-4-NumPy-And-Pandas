# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# Rename all the columns to lower case

# %%
df.columns=[i.lower() for i in df.columns]
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# Change the Index to be the Line Names

# %%
df.set_index('linename',inplace=True)

# %%
df.head()
# Out:
#            c/a  unit       scp station division        date      time  \
# linename
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#              desc  entries  \
# linename
# NQR456W   REGULAR  6736067
# NQR456W   REGULAR  6736087
# NQR456W   REGULAR  6736105
# NQR456W   REGULAR  6736180
# NQR456W   REGULAR  6736349
#
#           exits
# linename
# NQR456W                                             2283184
# NQR456W                                             2283188
# NQR456W                                             2283229
# NQR456W                                             2283314
# NQR456W                                             2283384

# %% [markdown]
# Change the index back

# %%
df.reset_index(inplace=True) 
df.head()
# Out:
#   linename   c/a  unit       scp station division        date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order

# %%
df['Num_Lines'] = df['linename'].map(lambda x: len(x))
df.sort_values(by=['Num_Lines'],ascending=False)
# Out:
#             linename    c/a  unit       scp         station division  \
# 132292  1237ACENQRSW   R151  R033  00-00-00  TIMES SQ-42 ST      IRT
# 2686    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2673    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2674    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2675    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2676    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2677    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2678    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2679    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2680    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2681    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2682    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2683    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2684    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2685    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2687    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2702    ACENQRS1237W   A021  R032  01-00-02  TIMES SQ-42 ST      BMT
# 2688    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2689    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2690    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2691    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2692    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2693    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2694    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2695    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2696    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2697    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2698    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2699    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2700    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# ...              ...    ...   ...       ...             ...      ...
# 112535             1  PTH04  R551  00-04-04    GROVE STREET      PTH
# 112534             1  PTH04  R551  00-04-04    GROVE STREET      PTH
# 112558             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112559             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112560             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112561             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112584             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112583             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112582             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112581             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112580             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112579             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112578             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112577             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112576             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112575             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112574             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112573             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112572             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112571             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112570             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112569             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112568             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112567             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112566             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112565             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112564             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112563             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112562             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 197624             R  TRAM2  R469  00-05-01   RIT-ROOSEVELT      RIT
#
#               date      time     desc  entries  \
# 132292  08/30/2018  00:00:00  REGULAR  1417952
# 2686    08/29/2018  16:00:00  REGULAR  2836145
# 2673    08/27/2018  16:00:00  REGULAR  2830710
# 2674    08/27/2018  20:00:00  REGULAR  2832048
# 2675    08/28/2018  00:00:00  REGULAR  2832325
# 2676    08/28/2018  04:00:00  REGULAR  2832359
# 2677    08/28/2018  08:00:00  REGULAR  2832561
# 2678    08/28/2018  09:57:08  REGULAR  2832815
# 2679    08/28/2018  12:00:00  REGULAR  2832994
# 2680    08/28/2018  16:00:00  REGULAR  2833390
# 2681    08/28/2018  20:00:00  REGULAR  2834686
# 2686                                              3311412
# 2673                                              3305818
# 2674                                              3306310
# 2675                                              3306433
# 2676                                              3306438
# 2677                                              3306716
# 2678                                              3307705
# 2679                                              3308064
# 2680                                              3308536
# 2681                                              3309190
# 2682                                              3309328
# 2683                                              3309348
# 2684                                              3309579
# 2685                                              3310943
# 2687                                              3312091
# 2702                                              1942027
# 2688                                              3312246
# 2689                                              3312261
# 2690                                              3312478
# 2691                                              3312826
# 2692                                              3313701
# 2693                                              3314206
# 2694                                              3314879
# 2695                                              3315042
# 2696                                              3315061
# 2697                                              3315242
# 2698                                              3316295
# 2699                                              3316775
# 2700                                              3317347
# ...                                                   ...
# 112535                                              30905
# 112534                                              30893
# 112558                                              12480
# 112559                                              12483
# 112560                                              12494
# 112561                                              12514
# 112584                                              13807
# 112583                                              13762
# 112582                                              13726
# 112581                                              13640
# 112580                                              13639
# 112579                                              13597
# 112578                                              13414
# 112577                                              13390
# 112576                                              13260
# 112575                                              13245
# 112574                                              13237
# 112573                                              13164
# 112572                                              13036
# 112571                                              13013
# 112570                                              12894
# 112569                                              12893
# 112568                                              12881
# 112567                                              12754
# 112566                                              12698
# 112565                                              12659
# 112564                                              12541
# 112563                                              12541
# 112562                                              12531
# 197624                                                348
#
#         Num_Lines
# 132292         12
# 2686           12
# 2673           12
# 2674           12
# 2675           12
# 2676           12
# 2677           12
# 2678           12
# 2679           12
# 2680           12
# 2681           12
# 2682           12
# 2683           12
# 2684           12
# 2685           12
# 2687           12
# 2702           12
# 2688           12
# 2689           12
# 2690           12
# 2691           12
# 2692           12
# 2693           12
# 2694           12
# 2695           12
# 2696           12
# 2697           12
# 2698           12
# 2699           12
# 2700           12
# ...           ...
# 112535          1
# 112534          1
# 112558          1
# 112559          1
# 112560          1
# 112561          1
# 112584          1
# 112583          1
# 112582          1
# 112581          1
# 112580          1
# 112579          1
# 112578          1
# 112577          1
# 112576          1
# 112575          1
# 112574          1
# 112573          1
# 112572          1
# 112571          1
# 112570          1
# 112569          1
# 112568          1
# 112567          1
# 112566          1
# 112565          1
# 112564          1
# 112563          1
# 112562          1
# 197624          1
#
# [197625 rows x 12 columns]

# %% [markdown]
# Write a function to clean a column name

# %%
def clean(col_name):
    cleaned = col_name.strip()
    return cleaned

# %%
df.columns = [clean(col) for col in df.columns]

# %%
df.columns
# Out:
# Index(['linename', 'c/a', 'unit', 'scp', 'station', 'division', 'date', 'time',
#        'desc', 'entries', 'exits', 'Num_Lines'],
#       dtype='object')

# %% [markdown]
# Group the Data by Day of Week and Plot the Sum of The Numeric Columns

# %%
df['date'] = pd.to_datetime(df['date'])
df['dayofweek'] = df['date'].dt.dayofweek
grouped = df.groupby('dayofweek').sum()
grouped.plot(kind='barh')
